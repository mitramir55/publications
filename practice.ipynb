# %%
from bs4 import BeautifulSoup
import requests, lxml, os
headers = {
    'User-agent':
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}

user = "1hMBs-8AAAAJ" # Ann Barcomb
params = {
   "user": user,
   "sortby": "pubdate",
   "hl": "en"
}

def get_articles(params):
  html = requests.get('https://scholar.google.com/citations', headers=headers, params=params).text
  soup = BeautifulSoup(html, 'lxml')
  print('Article info:')
  for article_info in soup.select('#gsc_a_b .gsc_a_t'):
    title = article_info.select_one('.gsc_a_at').text
    title_link = f"https://scholar.google.com{article_info.select_one('.gsc_a_at')['href']}"
    authors = article_info.select_one('.gsc_a_at+ .gs_gray').text
    publications = article_info.select_one('.gs_gray+ .gs_gray').text
    print(f'Title: {title}\nTitle link: {title_link}\nArticle Author(s): {authors}\nArticle Publication(s): {publications}\n')

get_articles()
# Out:
# Article info:
# Title: A validation of QDAcity-RE for domain modeling using qualitative data analysis
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:_kc_bZDykSQC
# Article Author(s): A Kaufmann, J Krause, N Harutyunyan, A Barcomb, D Riehle
# Article Publication(s): Requirements Engineering 27 (1), 31-51, 2022
#
# Title: Pattern discovery and validation using scientific research methods
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:3fE2CSJIrl8C
# Article Author(s): D Riehle, N Harutyunyan, A Barcomb
# Article Publication(s): arXiv preprint arXiv:2107.06065, 2021
#
# Title: 2020 Index IEEE Transactions on Software Engineering Vol. 46
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:YOwf2qJgpHMC
# Article Author(s): S Abdelwahed, KV Abhishekh, B Adams, K Ali, V Alizadeh, M Aniche, ...
# Article Publication(s): IEEE Transactions on Software Engineering 47 (1), 2021
#
# Title: Quo Vadis, Open Source? The Limits of Open Source Growth
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:ULOm3_A8WrAC
# Article Author(s): M Dorner, M Capraro, A Barcomb
# Article Publication(s): arXiv preprint arXiv:2008.07753, 2020
#
# Title: A Replication Study on Measuring the Growth of Open Source
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:4TOpqqG69KYC
# Article Author(s): M Dorner, M Capraro, A Barcomb, K Wnuk
# Article Publication(s): arXiv e-prints, arXiv: 2008.07753, 2020
#
# Title: The Ecosystem of openKONSEQUENZ, A User-Led Open Source Foundation
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:kNdYIx-mwKoC
# Article Author(s): B Schwab, D Riehle, A Barcomb, N Harutyunyan
# Article Publication(s): IFIP International Conference on Open Source Systems, 1-13, 2020
#
# Title: Managing episodic volunteers in free/libre/open source software
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:Zph67rFs4hoC
# Article Author(s): A Barcomb, KJ Stol, B Fitzgerald, D Riehle
# Article Publication(s):
#
# Title: Managing episodic volunteers in free/libre/open source software communities
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:KlAtU1dfN6UC
# Article Author(s): A Barcomb, KJ Stol, B Fitzgerald, D Riehle
# Article Publication(s): IEEE Transactions on Software Engineering, 2020
#
# Title: Supporting Interview Analysis with Autocoding
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:8k81kl-MbHgC
# Article Author(s): A Kaufmann, A Barcomb, D Riehle
# Article Publication(s): Hawaii International Conference on System Sciences, 2020
#
# Title: Managing Commercial Conflicts of Interest in Open Source Foundations
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:5nxA0vEk-isC
# Article Author(s): F Weikert, D Riehle, A Barcomb
# Article Publication(s): International Conference on Software Business 10, 2019
#
# Title: Why do episodic volunteers stay in FLOSS communities?
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:hqOjcs7Dif8C
# Article Author(s): A Barcomb, KJ Stol, D Riehle, B Fitzgerald
# Article Publication(s): 2019 IEEE/ACM 41st International Conference on Software Engineering (ICSE …, 2019
#
# Title: Retaining and managing episodic contributors in free/libre/open source software communities
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:MXK_kJrjxJIC
# Article Author(s): AS Barcomb
# Article Publication(s): University of Limerick, 2019
#
# Title: Integrating managerial preferences into the qualitative multi-criteria evaluation of team members
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:0EnyYjriUFMC
# Article Author(s): A Barcomb, N Jullien, P Meyer, AL Olteanu
# Article Publication(s): Multiple criteria decision making and aiding, 95-143, 2019
#
# Title: Uncovering the periphery: A qualitative survey of episodic volunteering in free/libre and open source software communities
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:UebtZRa9Y70C
# Article Author(s): A Barcomb, A Kaufmann, D Riehle, KJ Stol, B Fitzgerald
# Article Publication(s): IEEE Transactions on Software Engineering 46 (9), 962-980, 2018
#
# Title: Towards a protocol for inferring preferences using majority-rule sorting models
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:LkGwnXOMwfcC
# Article Author(s): AL Olteanu, P Meyer, A Barcomb, N Jullien
# Article Publication(s): International Conference on Algorithmic Decision Theory, 35-49, 2017
#
# Title: Integrating Managerial Preferences into the Qualitative Evaluation of Virtual Team Member
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:_FxGoFyzp5QC
# Article Author(s): A Barcomb, N Jullien, P Meyer, AL Olteanu
# Article Publication(s): Available at SSRN 2990261, 2017
#
# Title: Motivation and autonomy in global software development
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:roLk4NBRz8UC
# Article Author(s): J Noll, S Beecham, A Razzak, B Richardson, A Barcomb, I Richardson
# Article Publication(s): International Workshop on Global Sourcing of Information Technology and …, 2017
#
# Title: Episodic volunteering in open source communities
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:eQOLeE2rZwMC
# Article Author(s): A Barcomb
# Article Publication(s): Proceedings of the 20th International Conference on Evaluation and …, 2016
#
# Title: Using Students as a Distributed Coding Team for Validation through Intercoder Agreement
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:Y0pCki6q_DkC
# Article Author(s): A Kaufmann, A Barcomb, D Riehle
# Article Publication(s): https://opus4.kobv.de/opus4-fau/frontdoor/index/index/docId/7130, 2016
#
# Title: A Case Study of Episodic Volunteering in FLOSS Communities-Appendices
# Title link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=1hMBs-8AAAAJ&sortby=pubdate&citation_for_view=1hMBs-8AAAAJ:ufrVoPGSRksC
# Article Author(s): A Barcomb, D Riehle, A Kaufmann
# Article Publication(s):

# %%
from bs4 import BeautifulSoup
import requests, lxml, os
headers = {
    'User-agent':
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}
html = requests.get('https://scholar.google.com/citations?hl=en&user=m8dFEawAAAAJ', headers=headers)
soup = BeautifulSoup(html.text, 'lxml')
for container in soup.select('.gsc_rsb_aa'):
  author_name = container.select_one('#gsc_rsb_co a').text
  author_affiliations = container.select_one('.gsc_rsb_a_ext').text
  author_link = container.select_one('#gsc_rsb_co a')['href']
  print(f'{author_name}\n{author_affiliations}\nhttps://scholar.google.com{author_link}\n')
# Part of the output:

# %%
from bs4 import BeautifulSoup
import requests, lxml, os, json
headers = {
    'User-agent':
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}
params = {
  "q": "requirements engineering",
  "hl": "en",
}
html = requests.get('https://scholar.google.com/scholar', headers=headers, params=params).text
soup = BeautifulSoup(html, 'lxml')
# Scrape just PDF links
for pdf_link in soup.select('.gs_or_ggsm a'):
  pdf_file_link = pdf_link['href']
  print(pdf_file_link)
# JSON data will be collected here
data = []
# Container where all needed data is located
for result in soup.select('.gs_ri'):
  title = result.select_one('.gs_rt').text
  title_link = result.select_one('.gs_rt a')['href']
  publication_info = result.select_one('.gs_a').text
  snippet = result.select_one('.gs_rs').text
  cited_by = result.select_one('#gs_res_ccl_mid .gs_nph+ a')['href']
  related_articles = result.select_one('a:nth-child(4)')['href']
  try:
    all_article_versions = result.select_one('a~ a+ .gs_nph')['href']
  except:
    all_article_versions = None
  data.append({
    'title': title,
    'title_link': title_link,
    'publication_info': publication_info,
    'snippet': snippet,
    'cited_by': f'https://scholar.google.com{cited_by}',
    'related_articles': f'https://scholar.google.com{related_articles}',
    'all_article_versions': f'https://scholar.google.com{all_article_versions}',
  })
print(json.dumps(data, indent = 2, ensure_ascii = False))
# Part of the JSON Output:
# Out:
# https://dl.acm.org/doi/pdf/10.1145/337180.337184
# https://dl.acm.org/doi/pdf/10.1145/267580.267581
# https://dl.acm.org/doi/pdf/10.1145/336512.336523
# https://cs.uwaterloo.ca/~jmatlee/Papers/ICSE07c.pdf
# http://park.itc.u-tokyo.ac.jp/panda/kushiro/ReferencePaper/Requirements%20engineering/00487319.pdf
# [
#   {
#     "title": "Requirements engineering in the year 00: A research perspective",
#     "title_link": "https://dl.acm.org/doi/abs/10.1145/337180.337184",
#     "publication_info": "A Van Lamsweerde - … international conference on Software engineering, 2000 - dl.acm.org",
#     "snippet": "… Not only did this paper comprehensively explain the scope of requirements engineering; \nit also suggested goals, viewpoints, data, operations, agents, and resources as potential …",
#     "cited_by": "https://scholar.google.com/scholar?cites=17156964242204007411&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:8xumqBPIGe4J:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=17156964242204007411&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "[BOOK][B] Requirements engineering",
#     "title_link": "https://books.google.com/books?hl=en&lr=&id=RojbBwAAQBAJ&oi=fnd&pg=PR7&dq=requirements+engineering&ots=ChsVJPOTI0&sig=tDjUeUIK4xSyqsLFjV1PuPQyMlE",
#     "publication_info": "LA Macaulay - 2012 - books.google.com",
#     "snippet": "… of software engineering or computer … requirements and system Requirements Engineering \nbecause of its focus on the problems caused by the fact that Requirements Engineering …",
#     "cited_by": "https://scholar.google.com/scholar?cites=17730050520998003853&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:jcTQ0QLLDfYJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=17730050520998003853&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "Classification of research efforts in requirements engineering",
#     "title_link": "https://dl.acm.org/doi/abs/10.1145/267580.267581",
#     "publication_info": "P Zave - ACM Computing Surveys (CSUR), 1997 - dl.acm.org",
#     "snippet": "… ments engineering. For those readers who are not familiar with requirements engineering, it \nis … For those readers who do research in requirements engineering, it is offered in the hope …",
#     "cited_by": "https://scholar.google.com/scholar?cites=2787537474980417943&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:lxFMgpBSryYJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=2787537474980417943&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "Requirements engineering: a roadmap",
#     "title_link": "https://dl.acm.org/doi/abs/10.1145/336512.336523",
#     "publication_info": "B Nuseibeh, S Easterbrook - … on the Future of Software Engineering, 2000 - dl.acm.org",
#     "snippet": "… Dr Easterbrook regularly serves on program committees for conferences in requirements \nengineering, automated software engineering, and is General Chair for the International …",
#     "cited_by": "https://scholar.google.com/scholar?cites=17583760794092376146&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:UhBRi0cRBvQJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=17583760794092376146&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "Research directions in requirements engineering",
#     "title_link": "https://ieeexplore.ieee.org/abstract/document/4221627/",
#     "publication_info": "BHC Cheng, JM Atlee - Future of Software Engineering (FOSE' …, 2007 - ieeexplore.ieee.org",
#     "snippet": "… Although these activities are “related” to a system’s requirements, they play at most a … ’s \nrequirements; as such, we consider them to be outside the scope of requirements engineering. …",
#     "cited_by": "https://scholar.google.com/scholar?cites=777466033969324854&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:NmOsGz0dygoJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=777466033969324854&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "[BOOK][B] Requirements engineering: fundamentals, principles, and techniques",
#     "title_link": "https://dl.acm.org/doi/abs/10.5555/1869735",
#     "publication_info": "K Pohl - 2010 - dl.acm.org",
#     "snippet": "… \" on the field of requirements engineering where such did not exist … of software and systems \nengineering as opposed to a … , and techniques of requirements engineering based on …",
#     "cited_by": "https://scholar.google.com/scholar?cites=4187062461358511322&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:2pSl5R9vGzoJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.comNone"
#   },
#   {
#     "title": "Requirements engineering: the state of the practice",
#     "title_link": "https://ieeexplore.ieee.org/abstract/document/1241365/",
#     "publication_info": "CJ Neill, PA Laplante - IEEE software, 2003 - ieeexplore.ieee.org",
#     "snippet": "… Given all the questions regarding requirements engineering practices, we wanted to know \n… ’t think that their company did enough requirements engineering— only 29 percent felt that …",
#     "cited_by": "https://scholar.google.com/scholar?cites=11191303379929172541&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:PYpORiF_T5sJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=11191303379929172541&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "Requirements engineering with viewpoints",
#     "title_link": "https://digital-library.theiet.org/content/journals/10.1049/sej.1996.0002",
#     "publication_info": "G Kotonya, I Sommerville - Software Engineering Journal, 1996 - IET",
#     "snippet": "… have already discussed the notion of an indirect viewpoint; we believe the requirements \nengineering process is incomplete unless these viewpoints are considered. With the exception …",
#     "cited_by": "https://scholar.google.com/scholar?cites=2277407901566969852&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:_CeRlWv6mh8J:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=2277407901566969852&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "[BOOK][B] Social modeling for requirements engineering",
#     "title_link": "https://books.google.com/books?hl=en&lr=&id=ceNA3l1jOeAC&oi=fnd&pg=PP1&dq=requirements+engineering&ots=gIkFMvY-X1&sig=erDQ6a1XO3gJZq6CNJ2nq43gXT4",
#     "publication_info": "SK Eric, P Giorgini, N Maiden, J Mylopoulos - 2011 - books.google.com",
#     "snippet": "… down system requirements. This book offers a new approach to the requirements challenge, \n… recognized in the requirements engineering field, most requirements modeling techniques …",
#     "cited_by": "https://scholar.google.com/scholar?cites=4481849579379331816&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:6JKjU3K6Mj4J:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=4481849579379331816&hl=en&as_sdt=0,5"
#   },
#   {
#     "title": "[BOOK][B] The requirements engineering handbook",
#     "title_link": "https://books.google.com/books?hl=en&lr=&id=Rkulpi4N3JsC&oi=fnd&pg=PR11&dq=requirements+engineering&ots=L74fPMIafp&sig=ck8qGgnotre_rhz3AfGnNqwawN8",
#     "publication_info": "RR Young - 2004 - books.google.com",
#     "snippet": "… The purpose of this book is to help you improve the practice of requirements engineering. \nRequirements engineering is difficult. It's not just a simple matter of writing down what the cus…",
#     "cited_by": "https://scholar.google.com/scholar?cites=14107713896606594830&as_sdt=2005&sciodt=0,5&hl=en",
#     "related_articles": "https://scholar.google.com/scholar?q=related:DvcTCAuryMMJ:scholar.google.com/&scioq=requirements+engineering&hl=en&as_sdt=0,5",
#     "all_article_versions": "https://scholar.google.com/scholar?cluster=14107713896606594830&hl=en&as_sdt=0,5"
#   }
# ]

# %%
from serpapi import GoogleSearch
import os, json

params = {
  "api_key": os.getenv("API_KEY"),
  "engine": "google_scholar",
  "q": "samsung",
}
search = GoogleSearch(params)
results = search.get_dict()
# This print() looks pretty akward, 
# but the point is that you can grab everything you need in 2-3 lines of code as below.
for result in results['organic_results']:
  print(f"Title: {result['title']}\nPublication info: {result['publication_info']['summary']}\nSnippet: {result['snippet']}\nCited by: {result['inline_links']['cited_by']['link']}\nRelated Versions: {result['inline_links']['related_pages_link']}\n")
# If you want more readable code, here's one example.
data = []
for result in results['organic_results']:
  data.append({
    'title': result['title'],
    'publication_info': result['publication_info']['summary'],
    'snippet': result['snippet'],
    'cited_by': result['inline_links']['cited_by']['link'],
    'related_versions': result['inline_links']['related_pages_link'],
  })
print(json.dumps(data, indent = 2, ensure_ascii = False))
# Part of Non-JSON output:
# Out:
# https://serpapi.com/search
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15556/1243862319.py in <module>
#      10 # This print() looks pretty akward,
#      11 # but the point is that you can grab everything you need in 2-3 lines of code as below.
# ---> 12 for result in results['organic_results']:
#      13   print(f"Title: {result['title']}\nPublication info: {result['publication_info']['summary']}\nSnippet: {result['snippet']}\nCited by: {result['inline_links']['cited_by']['link']}\nRelated Versions: {result['inline_links']['related_pages_link']}\n")
#      14 # If you want more readable code, here's one example.
#
# KeyError: 'organic_results'

# %%
$ pip install requests
$ pip install lxml 
$ pip install beautifulsoup4
$ pip install google-search-results

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_scholar",
  "q": "biology",
  "api_key": "secret_api_key"
}

search = GoogleSearch(params)
results = search.get_dict()
organic_results = results["organic_results"]
# Out:
# https://serpapi.com/search
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15556/3818813265.py in <module>
#       9 search = GoogleSearch(params)
#      10 results = search.get_dict()
# ---> 11 organic_results = results["organic_results"]
#
# KeyError: 'organic_results'

# %%
results
# Out:
# {'error': 'Invalid API key. Your API key should be here: https://serpapi.com/manage-api-key'}
